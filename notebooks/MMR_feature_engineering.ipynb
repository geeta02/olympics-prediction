# %% [markdown]
# ### MMR Dataset

# %% [raw]
# WORK DISTRIBUTION
#
# JOHN -> FINAL GDP DATASET
#
# RISHI -> BMI DATASET
#
# ADITI -> OLYMPIC ,HDI , LE, EYS, CO2PROD DATASET
#
# MEENU -> MYS, GNIPC DATASET
#
# GEETHA -> MMR, PHDI DATASET
#
#
#
# For the allotted dataset please do the following :
#
# Descriptive Statistics & Summary Analysis
# Generate summary statistics (mean, median, min, max, quartiles, standard deviation).
# Check data distributions using statistical methods like skewness and kurtosis.
# * Analyze trends over time if applicable.
#  Identify correlations between numerical variables.
# * Find anomalies or unexpected patterns.
#
# Exploratory Data Analysis (EDA)
#
# Visualizing Key Insights
#
# Univariate Analysis (Single Variable)
# * Histogram → To show the distribution of HDI values.
# * KDE (Kernel Density Estimate) Plot → To visualize the smooth density curve of HDI values.
# * Boxplot → To detect outliers in HDI across different years.
# * Violin Plot → To show the distribution and density of HDI values in a more detailed way.
# * Bar Chart → To display the number of countries in different HDI ranges (e.g., low, medium, high).
#
#
# Bivariate Analysis (Two Variables)
# * Scatter Plot → To analyze the relationship between HDI values in two different time periods (e.g., 2000-2004 vs. 2008-2012).
# * Line Plot → To observe the trend of HDI over time for a specific country or globally.
# * Boxplot (Country-wise) → To compare HDI variations across multiple countries in different time periods.
# * Violin Plot → To compare HDI distributions across time periods.
# * Pairwise Scatter Plot (Pair Plot) → To visualize relationships between HDI values across different periods.
#
# Trend & Time-Series Analysis
# * Line Chart (Global HDI Trend) → To visualize the overall change in average HDI over time.
# * Line Chart (Country-Specific HDI Trend) → To track how HDI evolved for a particular country.
# * Area Chart → To highlight the proportion of countries in different HDI categories over time.
#
# Country-Wise Comparisons
# * Grouped Bar Chart → To compare HDI values across different time periods for selected countries.
# * Stacked Bar Chart → To visualize how HDI improvements are distributed among countries.
# * Top 10 and Bottom 10 Countries (Bar Plot) → To rank countries based on HDI in a specific time period.
# * Boxplot (Continental Comparison, if data is categorized by region) → To see variations between continents.
#
# Advanced & Statistical Plots
# * Regression Plot → To analyze the trend in HDI changes over time.
# * T-test or ANOVA Visualization → To compare HDI means statistically over time.
# * Histogram with Normal Curve Overlay → To check if HDI follows a normal distribution.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "/Users/geetharajamanickam/Downloads/DS Group Project/MMR_yearwise_avg.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#   iso3      country    1996-2000    2000-2004    2004-2008   2008-2012
# 0  AFG  Afghanistan  1389.824073  1273.243525  1071.398197  914.435116
# 1  ALB      Albania    16.871587    12.844594    10.606172    8.849643
# 2  DZA      Algeria   186.703561   154.546118   134.978911  112.069477
# 3  AND      Andorra          NaN          NaN          NaN         NaN
# 4  AGO       Angola   946.537299   773.582500   528.680926  384.804745

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iso3       206 non-null    object
#  1   country    206 non-null    object
#  2   1996-2000  195 non-null    float64
#  3   2000-2004  195 non-null    float64
#  4   2004-2008  195 non-null    float64
#  5   2008-2012  195 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 9.8+ KB

# %%
print('Summary Statistics: ')
df.describe()
# Out:
# Summary Statistics:
#          1996-2000    2000-2004    2004-2008    2008-2012
# count   195.000000   195.000000   195.000000   195.000000
# mean    289.873623   243.631244   212.438989   192.985599
# std     448.346719   328.217069   285.974281   264.326670
# min       4.086135     3.646787     3.262045     2.825993
# 25%      31.508503    24.034368    19.183327    16.461942
# 50%      86.565917    73.318022    72.302118    64.241038
# 75%     452.758140   383.406298   338.224289   286.070965
# max    4092.691688  1603.009512  1298.170566  1285.951471

# %%
print("Skewness: ")
df.iloc[:, 2:].skew()
# Out:
# Skewness:
# 1996-2000    3.937419
# 2000-2004    1.834081
# 2004-2008    1.803469
# 2008-2012    1.819907
# dtype: float64

# %%
print("Kurtosis: ")
df.iloc[:, 2:].kurt()
# Out:
# Kurtosis:
# 1996-2000    26.501617
# 2000-2004     3.264612
# 2004-2008     2.971350
# 2008-2012     2.983288
# dtype: float64

# %% [markdown]
# ### Correlation plot

# %%
corr_features = df.drop(columns = ['iso3', 'country'])
corr_matrix = corr_features.corr()
sns.heatmap(corr_matrix, cmap = 'Blues', annot = True)
plt.show()

# %% [markdown]
# #### Univariate analysis

# %%
num_cols = ['1996-2000', '2000-2004', '2004-2008', '2008-2012']
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    sns.histplot(df[col].dropna(), bins=30, kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f"Histogram of {col}")
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
plt.figure()
sns.boxplot(data=df[num_cols], palette="Set2")
plt.title("Boxplot of MMR values across years")
plt.xlabel("Year")
plt.ylabel("Value")
plt.show()
